# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd  
# pd.set_option("display.max_rows", None, "display.max_columns", None)

dict1 = {'AJ0': {'AJ0': 246113, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 3661, 'AVP': 328, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 2, 'NN0': 11, 'NN1': 11067, 'NN2': 40, 'NP0': 1093, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 554, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 13, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 1, 'VVB': 51, 'VVD': 1412, 'VVG': 7445, 'VVI': 330, 'VVN': 10724, 'VVZ': 0, 'XX0': 0, 'ZZ0': 11, '': 10304}, 'AJC': {'AJ0': 0, 'AJC': 6694, 'AJS': 5, 'AT0': 0, 'AV0': 1073, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 26, 'NN2': 0, 'NP0': 24, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 1, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 6, 'VVD': 0, 'VVG': 0, 'VVI': 4, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 88}, 'AJS': {'AJ0': 0, 'AJC': 0, 'AJS': 3751, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 1, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 1, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 60}, 'AT0': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 342544, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 8, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 9}, 'AV0': {'AJ0': 6938, 'AJC': 1372, 'AJS': 471, 'AT0': 429, 'AV0': 159284, 'AVP': 0, 'AVQ': 0, 'CJC': 14, 'CJS': 2682, 'CJT': 140, 'CRD': 0, 'DPS': 0, 'DT0': 2925, 'DTQ': 0, 'EX0': 2045, 'ITJ': 1, 'NN0': 0, 'NN1': 1346, 'NN2': 0, 'NP0': 25, 'ORD': 0, 'PNI': 3, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 4298, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 12, 'VBB': 49, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 1, 'VVD': 0, 'VVG': 12, 'VVI': 19, 'VVN': 24, 'VVZ': 0, 'XX0': 0, 'ZZ0': 1, '': 708}, 'AVP': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 3, 'AVP': 24338, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 16235, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 1}, 'AVQ': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 227, 'AVP': 0, 'AVQ': 8269, 'CJC': 0, 'CJS': 2830, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 4}, 'CJC': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 133836, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 1}, 'CJS': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 1294, 'AVP': 0, 'AVQ': 2273, 'CJC': 72, 'CJS': 52137, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 3818, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 1, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 2, 'VVG': 60, 'VVI': 0, 'VVN': 136, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 4}, 'CJT': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 29543, 'CRD': 0, 'DPS': 0, 'DT0': 166, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'CRD': {'AJ0': 2, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 54108, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 1, 'NN1': 5, 'NN2': 0, 'NP0': 6, 'ORD': 0, 'PNI': 0, 'PNP': 176, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 17, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 21, '': 2746}, 'DPS': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 57707, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 3, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 5}, 'DT0': {'AJ0': 859, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 5788, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 10988, 'CRD': 0, 'DPS': 0, 'DT0': 73845, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 1, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 10}, 'DTQ': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 23419, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 4}, 'EX0': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 9473, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 1}, 'ITJ': {'AJ0': 70, 'AJC': 0, 'AJS': 0, 'AT0': 967, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 2688, 'NN0': 0, 'NN1': 74, 'NN2': 2, 'NP0': 7, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 2, 'UNC': 3, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 2, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 41, '': 94}, 'NN0': {'AJ0': 7, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 1, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 12500, 'NN1': 17, 'NN2': 34, 'NP0': 32, 'ORD': 0, 'PNI': 0, 'PNP': 1, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 28, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 2, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 5, 'VVD': 1, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ':
 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 1, 'VVB': 8, 'VVD': 1, 'VVG': 0, 'VVI': 10, 'VVN': 0, 'VVZ': 2, 'XX0': 0, 'ZZ0': 12, '': 2460}, 'VBB': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 2, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 5, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 21200, 'VBD': 0, 'VBG': 0, 'VBI': 160, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 2}, 'VBD': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 50851, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 2}, 'VBG': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 3294, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 3}, 'VBI': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 18, 'VBD': 0, 'VBG': 0, 'VBI': 24503, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 1}, 'VBN': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 9232, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VBZ': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 5458, 'PRF': 0, 'PRP': 1, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 37353, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VDB': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 5140, 'VDD': 0, 'VDG': 0, 'VDI': 2, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 2}, 'VDD': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 4133, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VDG': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 771, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VDI': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 2530, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VDN': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 1000, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VDZ': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 1, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 2, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 2028, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 2}, 'VHB': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 10153, 'VHD': 0, 'VHG': 0, 'VHI': 5, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VHD': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 16876, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 874, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VHG': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 1347, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VHI': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 1, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 6929, 'VHD': 0, 'VHG': 0, 'VHI': 1, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VHN': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 823, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 10, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VHZ': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 354, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 8212, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0}, 'VM0': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 150, 'NN2': 0, 'NP0': 45, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 51221, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 3, 'VVN': 436, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 2}, 'VVB': {'AJ0': 796, 'AJC': 23, 'AJS': 0, 'AT0': 0, 'AV0': 12, 'AVP': 21, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 1, 'CRD': 1, 'DPS': 0, 'DT0': 51, 'DTQ': 0, 'EX0': 0, 'ITJ': 7, 'NN0': 15, 'NN1': 24967, 'NN2': 0, 'NP0': 352, 'ORD': 28, 'PNI': 0, 'PNP': 2, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 308, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 18, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 22, 'VVB': 10239, 'VVD': 69, 'VVG': 0, 'VVI': 23601, 'VVN': 758, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 1851}, 'VVD': {'AJ0': 2283, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 3, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 220, 'NN2': 0, 'NP0': 27, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 2, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 4, 'VVB': 90, 'VVD': 56437, 'VVG': 0, 'VVI': 163, 'VVN': 30016, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 454}, 'VVG': {'AJ0': 3847, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 3, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 5398, 'NN2': 0, 'NP0': 37, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 76, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 4, 'VVG': 49581, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 1033}, 'VVI': {'AJ0': 1406, 'AJC': 32, 'AJS': 0, 'AT0': 8, 'AV0': 50, 'AVP': 27, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 23, 'DTQ': 0, 'EX0': 0, 'ITJ': 1, 'NN0': 36, 'NN1': 18160, 'NN2': 0, 'NP0': 2, 'ORD': 106, 'PNI': 0, 'PNP': 1, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 715, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 1, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 17, 'VVB': 4631, 'VVD': 159, 'VVG': 0, 'VVI': 61290, 'VVN': 1013, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 354}, 'VVN': {'AJ0': 4836, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 4, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 217, 'NN2': 0, 'NP0': 9, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 67, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 6, 'VVB': 53, 'VVD': 19035, 'VVG': 0, 'VVI': 1412, 'VVN': 71970, 'VVZ': 0, 'XX0': 0, 'ZZ0': 0, '': 529}, 'VVZ': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 185, 'NN1': 0, 'NN2': 7162, 'NP0': 16, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 2, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 23403, 'XX0': 0, 'ZZ0': 0, '': 659}, 'XX0': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 0, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 0, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 0, 'ORD': 0, 'PNI': 0, 'PNP': 0, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 0, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 24927, 'ZZ0': 0, '': 1}, 'ZZ0': {'AJ0': 0, 'AJC': 0, 'AJS': 0, 'AT0': 767, 'AV0': 0, 'AVP': 0, 'AVQ': 0, 'CJC': 0, 'CJS': 0, 'CJT': 0, 'CRD': 22, 'DPS': 0, 'DT0': 0, 'DTQ': 0, 'EX0': 0, 'ITJ': 0, 'NN0': 0, 'NN1': 0, 'NN2': 0, 'NP0': 267, 'ORD': 0, 'PNI': 0, 'PNP': 58, 'PNQ': 0, 'PNX': 0, 'POS': 0, 'PRF': 0, 'PRP': 38, 'PUL': 0, 'PUN': 0, 'PUQ': 0, 'PUR': 0, 'TO0': 0, 'UNC': 0, 'VBB': 0, 'VBD': 0, 'VBG': 0, 'VBI': 0, 'VBN': 0, 'VBZ': 0, 'VDB': 0, 'VDD': 0, 'VDG': 0, 'VDI': 0, 'VDN': 0, 'VDZ': 0, 'VHB': 0, 'VHD': 0, 'VHG': 0, 'VHI': 0, 'VHN': 0, 'VHZ': 0, 'VM0': 0, 'VVB': 0, 'VVD': 0, 'VVG': 0, 'VVI': 0, 'VVN': 0, 'VVZ': 0, 'XX0': 11, 'ZZ0': 1491, '': 35}}

df = pd.DataFrame.from_dict(dict1, orient='columns')
df = df.replace(np.nan, 0)
df = df.sort_index(ascending=True, axis=1)
print(df.astype(int))
# Out:
#         AJ0   AJC   AJS     AT0     AV0  ...   VVI    VVN    VVZ    XX0   ZZ0
# AJ0  246113     0     0       0    6938  ...  1406   4836      0      0     0
# AJC       0  6694     0       0    1372  ...    32      0      0      0     0
# AJS       0     5  3751       0     471  ...     0      0      0      0     0
# AT0       0     0     0  342544     429  ...     8      0      0      0   767
# AV0    3661  1073     0       0  159284  ...    50      0      0      0     0
# ..      ...   ...   ...     ...     ...  ...   ...    ...    ...    ...   ...
# VVN   10724     0     0       0      24  ...  1013  71970      0      0     0
# VVZ       0     0     0       0       0  ...     0      0  23403      0     0
# XX0       0     0     0       0       0  ...     0      0      0  24927    11
# ZZ0      11     0     0       0       1  ...     0      0      0      0  1491
#       10304    88    60       9     708  ...   354    529    659      1    35
#
# [62 rows x 61 columns]

# %%
df2 = df
df2 = df2/ df2.sum(axis=1)

# %%
import seaborn as sns
plt.figure(figsize = (20,15))
tst = sns.heatmap(df2 ,xticklabels=1 , yticklabels=1 , cmap = 'Blues' ,vmin=0 ,vmax=0.1)
#tst.set(xlabel='Predicted tags' , ylabel = 'Actual tags')
plt.ylabel('Predicted tags',fontsize =24)
plt.xlabel('Actual tags',fontsize =24)
plt.title('Confusion Matrix for POS tags on test dataset' , fontsize = 32)

fig = tst.get_figure()
fig.savefig('sample2.png')
